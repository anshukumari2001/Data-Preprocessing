# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("Prediction.csv")
data
# Out:
#    Month_with_date  Counting_from_april  Confirmed_Cases  Recovered_Cases  \
# 0     April-1-2020                    1             2059              169
# 1     April-2-2020                    2             2545              191
# 2     April-3-2020                    3             3105              230
# 3     April-4-2020                    4             3684              286
# 4     April-5-2020                    5             4293              329
# 5     April-6-2020                    6             4777              394
# 6     April-7-2020                    7             5350              469
# 7     April-8-2020                    8             5915              565
# 8     April-9-2020                    9             6728              635
# 9    April-10-2020                   10             7599              786
# 10   April-11-2020                   11             8453              972
# 11   April-12-2020                   12             9211             1086
# ...

# %%
data["Confirmed_Cases"].isnull()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# 36    False
# 37    False
# 38    False
# 39    False
# 40    False
# 41    False
# 42    False
# 43    False
# 44    False
# 45    False
# 46    False
# 47    False
# 48    False
# 49    False
# 50    False
# 51    False
# 52    False
# 53    False
# 54    False
# 55    False
# Name: Confirmed_Cases, dtype: bool

# %%
data["Confirmed_Cases"].notnull()
# Out:
# 0     True
# 1     True
# 2     True
# 3     True
# 4     True
# 5     True
# 6     True
# 7     True
# 8     True
# 9     True
# 10    True
# 11    True
# 12    True
# 13    True
# 14    True
# 15    True
# 16    True
# 17    True
# 18    True
# 19    True
# 20    True
# 21    True
# 22    True
# 23    True
# 24    True
# 25    True
# 26    True
# 27    True
# 28    True
# 29    True
# 30    True
# 31    True
# 32    True
# 33    True
# 34    True
# 35    True
# 36    True
# 37    True
# 38    True
# 39    True
# 40    True
# 41    True
# 42    True
# 43    True
# 44    True
# 45    True
# 46    True
# 47    True
# 48    True
# 49    True
# 50    True
# 51    True
# 52    True
# 53    True
# 54    True
# 55    True
# Name: Confirmed_Cases, dtype: bool

# %%
#data.drop('Deceased_Cases',axis=1)

# %%
data.drop(['Deceased_Cases','Recovered_Cases'],axis=1)
# Out:
#    Month_with_date  Counting_from_april  Confirmed_Cases
# 0     April-1-2020                    1             2059
# 1     April-2-2020                    2             2545
# 2     April-3-2020                    3             3105
# 3     April-4-2020                    4             3684
# 4     April-5-2020                    5             4293
# 5     April-6-2020                    6             4777
# 6     April-7-2020                    7             5350
# 7     April-8-2020                    8             5915
# 8     April-9-2020                    9             6728
# 9    April-10-2020                   10             7599
# 10   April-11-2020                   11             8453
# 11   April-12-2020                   12             9211
# 12   April-13-2020                   13            10454
# 13   April-14-2020                   14            11485
# 14   April-15-2020                   15            12371
# ...

# %%
ser = pd.Series(['May,',57,34.5,np.nan])

# %%
ser.isnull()
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# dtype: bool

# %%
data["Counting_from_april"].replace(1,np.nan)
# Out:
# 0      NaN
# 1      2.0
# 2      3.0
# 3      4.0
# 4      5.0
# 5      6.0
# 6      7.0
# 7      8.0
# 8      9.0
# 9     10.0
# 10    11.0
# 11    12.0
# 12    13.0
# 13    14.0
# 14    15.0
# 15    16.0
# 16    17.0
# 17    18.0
# 18    19.0
# 19    20.0
# 20    21.0
# 21    22.0
# 22    23.0
# 23    24.0
# 24    25.0
# 25    26.0
# 26    27.0
# 27    28.0
# 28    29.0
# 29    30.0
# 30    31.0
# 31    32.0
# 32    33.0
# 33    34.0
# 34    35.0
# 35    36.0
# 36    37.0
# 37    38.0
# 38    39.0
# 39    40.0
# 40    41.0
# 41    42.0
# 42    43.0
# 43    44.0
# 44    45.0
# 45    46.0
# 46    47.0
# 47    48.0
# 48    49.0
# 49    50.0
# 50    51.0
# 51    52.0
# 52    53.0
# 53    54.0
# 54    55.0
# 55    56.0
# Name: Counting_from_april, dtype: float64

# %%
data.drop(data.columns[2],axis=1)
# Out:
#    Month_with_date  Counting_from_april  Recovered_Cases  Deceased_Cases
# 0     April-1-2020                    1              169              53
# 1     April-2-2020                    2              191              69
# 2     April-3-2020                    3              230              83
# 3     April-4-2020                    4              286              96
# 4     April-5-2020                    5              329             118
# 5     April-6-2020                    6              394             134
# 6     April-7-2020                    7              469             161
# 7     April-8-2020                    8              565             181
# 8     April-9-2020                    9              635             227
# 9    April-10-2020                   10              786             249
# 10   April-11-2020                   11              972             290
# 11   April-12-2020                   12             1086             332
# ...

# %%
data.drop(data.index[[2,4]])
# Out:
#    Month_with_date  Counting_from_april  Confirmed_Cases  Recovered_Cases  \
# 0     April-1-2020                    1             2059              169
# 1     April-2-2020                    2             2545              191
# 3     April-4-2020                    4             3684              286
# 5     April-6-2020                    6             4777              394
# 6     April-7-2020                    7             5350              469
# 7     April-8-2020                    8             5915              565
# 8     April-9-2020                    9             6728              635
# 9    April-10-2020                   10             7599              786
# 10   April-11-2020                   11             8453              972
# 11   April-12-2020                   12             9211             1086
# 12   April-13-2020                   13            10454             1198
# 13   April-14-2020                   14            11485             1365
# ...

# %%
data.drop_duplicates()
# Out:
#    Month_with_date  Counting_from_april  Confirmed_Cases  Recovered_Cases  \
# 0     April-1-2020                    1             2059              169
# 1     April-2-2020                    2             2545              191
# 2     April-3-2020                    3             3105              230
# 3     April-4-2020                    4             3684              286
# 4     April-5-2020                    5             4293              329
# 5     April-6-2020                    6             4777              394
# 6     April-7-2020                    7             5350              469
# 7     April-8-2020                    8             5915              565
# 8     April-9-2020                    9             6728              635
# 9    April-10-2020                   10             7599              786
# 10   April-11-2020                   11             8453              972
# 11   April-12-2020                   12             9211             1086
# ...
