# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("Prediction.csv")
data
# Out:
#    Month_with_date  Counting_from_april  Confirmed_Cases  Recovered_Cases  \
# 0     April-1-2020                    1             2059              169
# 1     April-2-2020                    2             2545              191
# 2     April-3-2020                    3             3105              230
# 3     April-4-2020                    4             3684              286
# 4     April-5-2020                    5             4293              329
# 5     April-6-2020                    6             4777              394
# 6     April-7-2020                    7             5350              469
# 7     April-8-2020                    8             5915              565
# 8     April-9-2020                    9             6728              635
# 9    April-10-2020                   10             7599              786
# 10   April-11-2020                   11             8453              972
# 11   April-12-2020                   12             9211             1086
# ...

# %%
data.groupby('Counting_from_april')['Confirmed_Cases'].mean()
# Out:
# Counting_from_april
# 1       2059
# 2       2545
# 3       3105
# 4       3684
# 5       4293
# 6       4777
# 7       5350
# 8       5915
# 9       6728
# 10      7599
# 11      8453
# 12      9211
# 13     10454
# 14     11485
# 15     12371
# 16     13432
# 17     14354
# 18     15725
# 19     17305
# 20     18544
# 21     20081
# 22     21373
# 23     23040
# 24     24448
# 25     26238
# 26     27890
# 27     29458
# 28     31360
# 29     33065
# 30     34866
# 31     37262
# 32     39826
# 33     42778
# 34     46434
# 35     49405
# 36     53007
# 37     56351
# 38     59690
# 39     62865
# 40     67176
# 41     70768
# 42     74330
# 43     78056
# 44     82047
# 45     85855
# 46     90649
# 47     95698
# 48    100326
# 49    106480
# 50    112200
# 51    118223
# 52    124759
# 53    131422
# 54    138535
# 55    144949
# 56    150815
# Name: Confirmed_Cases, dtype: int64

# %%
 data.groupby(['Counting_from_april','Month_with_date'])['Confirmed_Cases'].mean()
# Out:
# Counting_from_april  Month_with_date
# 1                    April-1-2020         2059
# 2                    April-2-2020         2545
# 3                    April-3-2020         3105
# 4                    April-4-2020         3684
# 5                    April-5-2020         4293
# 6                    April-6-2020         4777
# 7                    April-7-2020         5350
# 8                    April-8-2020         5915
# 9                    April-9-2020         6728
# 10                   April-10-2020        7599
# 11                   April-11-2020        8453
# 12                   April-12-2020        9211
# 13                   April-13-2020       10454
# 14                   April-14-2020       11485
# 15                   April-15-2020       12371
# 16                   April-16-2020       13432
# 17                   April-17-2020       14354
# 18                   April-18-2020       15725
# 19                   April-19-2020       17305
# ...

# %%
dff= {
    "Name":['Anshu','Harsh','Ginni'],
    "Roll_no.": [6,16,17],
    "Location": ['Nangloi','peeragadhi','Narela']
}

# %%
dfff = {
    "Name":['Ishika','Jyoti','Ginni'],
    "Roll_no.": [6,16,18],
    "Location": ['Nangloi','peeragadhi','Narela']
}

# %%
time_take= pd.date_range('01/01/2020',periods=200000,freq='50s')

# %%
df= pd.DataFrame()

# %%
df["Datetime"]=time_take

# %%
df
# Out:
#                   Datetime
# 0      2020-01-01 00:00:00
# 1      2020-01-01 00:00:50
# 2      2020-01-01 00:01:40
# 3      2020-01-01 00:02:30
# 4      2020-01-01 00:03:20
# ...                    ...
# 199995 2020-04-25 17:42:30
# 199996 2020-04-25 17:43:20
# 199997 2020-04-25 17:44:10
# 199998 2020-04-25 17:45:00
# 199999 2020-04-25 17:45:50
#
# [200000 rows x 1 columns]

# %%
df["Year"]=df.Datetime.dt.year

# %%
df["Month"]=df.Datetime.dt.month

# %%
df["Day"]=df.Datetime.dt.day

# %%
df["Weekday_name"]=df.Datetime.dt.weekday_name

# %%
df["Hour"]=df.Datetime.dt.hour

# %%
df["Minute"]=df.Datetime.dt.minute

# %%
df["Second"]=df.Datetime.dt.second

# %%
df["Microsecond"]=df.Datetime.dt.microsecond

# %%
df
# Out:
#                   Datetime  Year  Month  Day Weekday_name  Hour  Minute  \
# 0      2020-01-01 00:00:00  2020      1    1    Wednesday     0       0
# 1      2020-01-01 00:00:50  2020      1    1    Wednesday     0       0
# 2      2020-01-01 00:01:40  2020      1    1    Wednesday     0       1
# 3      2020-01-01 00:02:30  2020      1    1    Wednesday     0       2
# 4      2020-01-01 00:03:20  2020      1    1    Wednesday     0       3
# ...                    ...   ...    ...  ...          ...   ...     ...
# 199995 2020-04-25 17:42:30  2020      4   25     Saturday    17      42
# 199996 2020-04-25 17:43:20  2020      4   25     Saturday    17      43
# 199997 2020-04-25 17:44:10  2020      4   25     Saturday    17      44
# 199998 2020-04-25 17:45:00  2020      4   25     Saturday    17      45
# 199999 2020-04-25 17:45:50  2020      4   25     Saturday    17      45
#
#         Second  Microsecond
# 0            0            0
# 1           50            0
# ...

# %%
data1= pd.concat([data,data],axis=0)

# %%
data1
# Out:
#    Month_with_date  Counting_from_april  Confirmed_Cases  Recovered_Cases  \
# 0     April-1-2020                    1             2059              169
# 1     April-2-2020                    2             2545              191
# 2     April-3-2020                    3             3105              230
# 3     April-4-2020                    4             3684              286
# 4     April-5-2020                    5             4293              329
# ..             ...                  ...              ...              ...
# 51     May-22-2020                   52           124759            51833
# 52     May-23-2020                   53           131422            54409
# 53     May-24-2020                   54           138535            57694
# 54     May-25-2020                   55           144949            60706
# 55     May-26-2020                   56           150815            64277
#
#     Deceased_Cases
# 0               53
# 1               69
# ...

# %%
data1= pd.merge(data,data)

# %%
data1
# Out:
#    Month_with_date  Counting_from_april  Confirmed_Cases  Recovered_Cases  \
# 0     April-1-2020                    1             2059              169
# 1     April-2-2020                    2             2545              191
# 2     April-3-2020                    3             3105              230
# 3     April-4-2020                    4             3684              286
# 4     April-5-2020                    5             4293              329
# 5     April-6-2020                    6             4777              394
# 6     April-7-2020                    7             5350              469
# 7     April-8-2020                    8             5915              565
# 8     April-9-2020                    9             6728              635
# 9    April-10-2020                   10             7599              786
# 10   April-11-2020                   11             8453              972
# 11   April-12-2020                   12             9211             1086
# ...
